# %% [markdown]
# #### 1. Import necessary libraries

# %%
from bs4 import BeautifulSoup
import requests
import time, os, random
import re
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
driver = webdriver.Chrome(chromedriver)
# Out:
# /var/folders/4q/s5vk58v95472hjx15zb8y_940000gn/T/ipykernel_56759/2060176432.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)

# %% [markdown]
# #### 2. Get total 23 pages of monitor listings on BestBuy.com

# %%
pages=['https://www.bestbuy.com/site/searchpage.jsp?id=pcat17071&st=monitor']
for i in range(2,24):
    new_url = 'https://www.bestbuy.com/site/searchpage.jsp?cp='+str(i)+'&id=pcat17071&st=monitor'
    pages.append(new_url)
pages[-3:]
# Out:
# ['https://www.bestbuy.com/site/searchpage.jsp?cp=21&id=pcat17071&st=monitor',
#  'https://www.bestbuy.com/site/searchpage.jsp?cp=22&id=pcat17071&st=monitor',
#  'https://www.bestbuy.com/site/searchpage.jsp?cp=23&id=pcat17071&st=monitor']

# %% [markdown]
# #### 3. Iterate though pages to get each monitor link, product_name, brand, price, rating, review_count

# %%
main_page="https://www.bestbuy.com"
product_link=[]
product_name=[]
brand=[]
price=[]
rating=[]
review_count=[]

# %%
for page in pages:
    driver.get(page)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    time.sleep(2)
    
    ratings=[item.text.split(" ")[1] for item in soup.find(class_="sku-item-list")('p',class_="visually-hidden")]
    rating.extend(ratings)
    reviews=[item.text.split(" ")[-2] for item in soup.find(class_="sku-item-list")('p',class_="visually-hidden")]   
    review_count.extend(reviews)
    
    for ol in soup.find(class_="sku-item-list"):
        for li in ol.find_all('h4'):
            for link in li.find_all('a'):
                product_link.append(main_page+link['href'])
                product_name.append(link.text)
                brand.append(link.text.split(' ')[0])

        for price_ in ol.find_all('div', class_="price-block"):
            price.append(price_('span')[0].text.split(">$")[-1])

# %%
len(set(product_link))
# Out:
# 551

# %%
print({"product_link":len(product_link),
       "product_name":len(product_name),
       "brand":len(brand),
       "price":len(price),
       "rating":len(rating),
       "review_count":len(review_count)
    
      })
# Out:
# {'product_link': 574, 'product_name': 574, 'brand': 574, 'price': 574, 'rating': 574, 'review_count': 574}

# %%
import pandas as pd
df= pd.DataFrame(
    {'product_link': product_link,
     'product_name' : product_name,
     'brand':brand,
     'current_price':price,
     'rating': rating,
     'review_count':review_count
    })
df
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 569  https://www.bestbuy.com/site/apple-studio-disp...
# 570  https://www.bestbuy.com/site/dell-geek-squad-c...
# 571  https://www.bestbuy.com/site/dell-geek-squad-c...
# 572  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 573  https://www.bestbuy.com/site/acer-predator-xb3...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 569  Apple - Studio Display - Standard Glass Tilt a...    Apple     $1,999.99
# 570  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 571  Dell - Geek Squad Certified Refurbished UltraS...     Dell     $3,599.99
# 572  HP - Geek Squad Certified Refurbished 23.8" IP...       HP       $179.99
# 573  Acer Predator XB3 - 27" Display WQHD 2560x1440...     Acer       $414.99
#
#     rating review_count
# 0      4.6         1838
# 1      4.7         5106
# 2      4.5          425
# 3      4.8          277
# 4      4.6         1840
# ..     ...          ...
# 569    Yet          Yet
# 570    Yet          Yet
# 571    Yet          Yet
# 572    Yet          Yet
# 573    Yet          Yet
#
# [574 rows x 6 columns]

# %%
# A bit of data cleaning
df.product_link.nunique()
# Out:
# 551

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 569  https://www.bestbuy.com/site/apple-studio-disp...
# 570  https://www.bestbuy.com/site/dell-geek-squad-c...
# 571  https://www.bestbuy.com/site/dell-geek-squad-c...
# 572  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 573  https://www.bestbuy.com/site/acer-predator-xb3...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 569  Apple - Studio Display - Standard Glass Tilt a...    Apple     $1,999.99
# 570  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 571  Dell - Geek Squad Certified Refurbished UltraS...     Dell     $3,599.99
# 572  HP - Geek Squad Certified Refurbished 23.8" IP...       HP       $179.99
# 573  Acer Predator XB3 - 27" Display WQHD 2560x1440...     Acer       $414.99
#
#     rating review_count
# 0      4.6         1838
# 1      4.7         5106
# 2      4.5          425
# 3      4.8          277
# 4      4.6         1840
# ..     ...          ...
# 569    Yet          Yet
# 570    Yet          Yet
# 571    Yet          Yet
# 572    Yet          Yet
# 573    Yet          Yet
#
# [551 rows x 6 columns]

# %%
# Save the data to local 
import os  
df.to_csv('Monitor_info.csv',index=False)

# %% [markdown]
# #### 4. Iterate through product links to extract monitor features

# %%
df=pd.read_csv('Monitor_info.csv')
df
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/apple-studio-disp...
# 547  https://www.bestbuy.com/site/dell-geek-squad-c...
# 548  https://www.bestbuy.com/site/dell-geek-squad-c...
# 549  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 550  https://www.bestbuy.com/site/acer-predator-xb3...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 546  Apple - Studio Display - Standard Glass Tilt a...    Apple     $1,999.99
# 547  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 548  Dell - Geek Squad Certified Refurbished UltraS...     Dell     $3,599.99
# 549  HP - Geek Squad Certified Refurbished 23.8" IP...       HP       $179.99
# 550  Acer Predator XB3 - 27" Display WQHD 2560x1440...     Acer       $414.99
#
#     rating review_count
# 0      4.6         1838
# 1      4.7         5106
# 2      4.5          425
# 3      4.8          277
# 4      4.6         1840
# ..     ...          ...
# 546    Yet          Yet
# 547    Yet          Yet
# 548    Yet          Yet
# 549    Yet          Yet
# 550    Yet          Yet
#
# [551 rows x 6 columns]

# %%
list(df['product_link'])[0:3]
# Out:
# ['https://www.bestbuy.com/site/samsung-t350-series-24-ips-led-fhd-freesync-hdmi-vga-dark-blue-gray/6420870.p?skuId=6420870',
#  'https://www.bestbuy.com/site/samsung-390-series-24-led-curved-fhd-freesync-monitor-hdmi-vga-high-glossy-black/5044601.p?skuId=5044601',
#  'https://www.bestbuy.com/site/lg-34-ultrawide-full-hd-hdr-monitor-with-freesync/6451082.p?skuId=6451082']

# %%
linklink=[]
Refresh_Rate=[]
Resolution=[]
Contrast_Ratio=[]
Response_Time=[]
Display_Type=[]
Panel_Type=[]
Synchronization_Technology=[]
Curved_Screen=[]
Pixel_Density=[]
Brightness=[]
Screen_Size=[]
HDR=[]
Smart_Display=[]
Touch_Screen=[]
Quantum_Dot_Technology=[]
Headphone_Jack=[]
Voice_Assistant=[]
Wall_Mountable=[]
Speaker=[]
Webcam=[]
Weight=[]
Power_Consumption=[]
Anti_Glare=[]

# %%
products=list(df['product_link'])[170:]

for product in products:
    index = products.index(product)
    driver.get(product)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    time.sleep(1 + 2*random.random())
    print(index,product)
    linklink.append(product)
    
    #Refresh_Rate
    refresh=soup.find(class_="display-name v-fw-medium body-copy", text="Refresh Rate")
    if refresh==None:
        Refresh_Rate.append(None)
    if refresh!=None:
        Refresh_Rate.append(refresh.parent.parent.parent.nextSibling.text.strip("Hz") )
    
    #Resolution
    resolution=soup.find(class_="display-name v-fw-medium body-copy", text="Maximum Resolution")
    if resolution==None:
        Resolution.append(None)
    if resolution!=None:
        Resolution.append(resolution.parent.parent.parent.nextSibling.text)
    
    #Contrast Ratio
    contrast=soup.find(class_="display-name v-fw-medium body-copy", text="Contrast Ratio")
    if contrast==None:
        Contrast_Ratio.append(None)
    if contrast!=None:
        Contrast_Ratio.append(contrast.parent.parent.parent.nextSibling.text[:-2].replace(",",""))
    
    #Response Time
    find_response=soup.find(class_="display-name v-fw-medium body-copy", text="Response Time")
    if find_response==None:
        Response_Time.append(None)
    if find_response!=None:
        Response_Time.append(find_response.parent.parent.parent.nextSibling.text.strip(" milliseconds"))
        
    #Display Type
    display=soup.find(class_="row-title", text=re.compile("Display Type"))
    if display==None:
        Display_Type.append(None)
    if display!=None:
        Display_Type.append(display.parent.nextSibling.text)    
    
    #Panel Type
    panel=soup.find(class_="display-name v-fw-medium body-copy", text="Panel Type")
    if panel==None:
        Panel_Type.append(None)
    if panel!=None:
        Panel_Type.append(panel.parent.parent.parent.nextSibling.text)
        
    #Synchronization Technology
    synchronization=soup.find(class_="display-name v-fw-medium body-copy", text="Synchronization Technology")
    if synchronization==None:
        Synchronization_Technology.append(None)
    if synchronization!=None:
        Synchronization_Technology.append(synchronization.parent.parent.parent.nextSibling.text)
    
    #Curved_Screen
    curved=soup.find(class_="row-title", text=re.compile("Curved Screen"))
    if curved==None:
        Curved_Screen.append(None)
    if curved!=None:
        Curved_Screen.append(curved.parent.nextSibling.text)
    
    #Pixel Density
    pixel=soup.find(class_="display-name v-fw-medium body-copy", text="Pixel Density")
    if pixel==None:
        Pixel_Density.append(None)
    if pixel!=None:
        Pixel_Density.append(pixel.parent.parent.parent.nextSibling.text.strip(" pixels per inch"))

    #Brightness
    bright=soup.find(class_="display-name v-fw-medium body-copy", text="Brightness")
    if bright==None:
        Brightness.append(None)
    if bright!=None:
        Brightness.append(bright.parent.parent.parent.nextSibling.text.strip(" candela per square meter"))
                
    ##Screen Size
    size=soup.find(class_="display-name v-fw-medium body-copy", text="Screen Size")
    if size==None:
        Screen_Size.append(None)
    if size!=None:
        Screen_Size.append(size.parent.parent.parent.nextSibling.text.strip(" inches"))  
    
    
    #High Dynamic Range (HDR)
    hdr=soup.find(class_="display-name v-fw-medium body-copy", text="High Dynamic Range (HDR)")
    if hdr==None:
        HDR.append(None)
    if hdr!=None:
        HDR.append(hdr.parent.parent.parent.nextSibling.text)
        
    #Smart Display
    smart=soup.find(class_="display-name v-fw-medium body-copy", text="Smart Display")
    if smart==None:
        Smart_Display.append(None)
    if smart!=None:
        Smart_Display.append(smart.parent.parent.parent.nextSibling.text)

    #Touch Screen
    touch=soup.find(class_="display-name v-fw-medium body-copy", text="Touch Screen")
    if touch==None:
        Touch_Screen.append(None)
    if touch!=None:
        Touch_Screen.append(touch.parent.parent.parent.nextSibling.text)

    #Quantum_Dot_Technology
    quantum=soup.find(class_="display-name v-fw-medium body-copy", text="Quantum Dot Technology")
    if quantum==None:
        Quantum_Dot_Technology.append(None)
    if quantum!=None:
        Quantum_Dot_Technology.append(quantum.parent.parent.parent.nextSibling.text)

    #Headphone_Jack
    headphone=soup.find(class_="display-name v-fw-medium body-copy", text="Headphone Jack")
    if headphone==None:
        Headphone_Jack.append(None)
    if headphone!=None:
        Headphone_Jack.append(headphone.parent.parent.parent.nextSibling.text)

    #Voice Assistant Built-in
    voice=soup.find(class_="display-name v-fw-medium body-copy", text="Voice Assistant Built-in")
    if voice==None:
        Voice_Assistant.append(None)
    if voice!=None:
        Voice_Assistant.append(voice.parent.parent.parent.nextSibling.text)
        
    #Wall Mountable
    mount=soup.find(class_="display-name v-fw-medium body-copy", text="Wall Mountable")
    if mount==None:
        Wall_Mountable.append(None)
    if mount!=None:
        Wall_Mountable.append(mount.parent.parent.parent.nextSibling.text)

    #Integrated Speaker(s)
    speaker=soup.find(class_="row-title", text=re.compile("Speaker"))
    if speaker==None:
        Speaker.append(None)
    if speaker!=None:
        Speaker.append(speaker.parent.nextSibling.text)   

    #Built-In Webcam 
    power=soup.find(class_="row-title", text=re.compile("Power Consumption"))
    if power==None:
        Power_Consumption.append(None)
    if power!=None:
        Power_Consumption.append(power.parent.nextSibling.text[:-5])  
        
    #Weight
    weight=soup.find(class_="display-name v-fw-medium body-copy", text="Product Weight")
    if weight==None:
        Weight.append(None)
    if weight!=None:
        Weight.append(weight.parent.parent.parent.nextSibling.text.strip(" pounds"))
        
    #Power Consumption 
    webcam=soup.find(class_="row-title", text=re.compile("Webcam"))
    if webcam==None:
        Webcam.append(None)
    if webcam!=None:
        Webcam.append(webcam.parent.nextSibling.text)   
        
    #Anti_Glare
    glare=soup.find(class_="display-name v-fw-medium body-copy", text="Anti-Glare")
    if glare==None:
        Anti_Glare.append(None)
    if glare!=None:
        Anti_Glare.append(glare.parent.parent.parent.nextSibling.text)
# Out:
# 0 https://www.bestbuy.com/site/acer-nitro-xv340ck-pbmiipphzx-34-qhd-monitor-hdmi/6425560.p?skuId=6425560
# 1 https://www.bestbuy.com/site/asus-tuf-24-5-ips-fhd-280hz-fast-1ms-g-sync-gaming-monitor-with-displayhdr-400/6421623.p?skuId=6421623
# 2 https://www.bestbuy.com/site/lg-27-ultragear-uhd-nano-ips-1ms-144hz-g-sync-compatible-gaming-monitor-with-hdr-displayport-hdmi-usb-black/6423550.p?skuId=6423550
# 3 https://www.bestbuy.com/site/viewsonic-21-5-usb-3-0-ips-led-fhd-monitor-displayport-hdmi-usb-vga/6258057.p?skuId=6258057
# 4 https://www.bestbuy.com/site/hp-27-ips-led-fhd-freesync-monitor-hdmi-x2-vga-with-integrated-speakers-ceramic-white/6478137.p?skuId=6478137
# 5 https://www.bestbuy.com/site/dell-22-monitor--e2221hn-54-7cm-21-5-black-black/6465152.p?skuId=6465152
# 6 https://www.bestbuy.com/site/asus-proart-27-ips-4k-professional-usb-c-monitor-with-height-adjustable-displayporthdmi/6450748.p?skuId=6450748
# 7 https://www.bestbuy.com/site/lg-ultragear-34-nano-ips-curved-219-wqhd-g-sync-ultimate-monitor-with-vesa-displayhdr-600-hdmi-displayport-usb-x2-black/6451084.p?skuId=6451084
# 8 https://www.bestbuy.com/site/viewsonic-27-ips-led-fhd-monitor-displayport-hdmi-vga/6504146.p?skuId=6504146
# 9 https://www.bestbuy.com/site/asus-tuf-vg289q1a-widescreen-gaming-lcd-monitor-black-black/6454340.p?skuId=6454340
# 10 https://www.bestbuy.com/site/viewsonic-vx2485-mhu-24-inch-1080p-ips-monitor-black/6400629.p?skuId=6400629
# 11 https://www.bestbuy.com/site/viewsonic-31-5-lcd-curved-fhd-monitor-displayport-hdmi/6431196.p?skuId=6431196
# 12 https://www.bestbuy.com/site/asus-tuf-gaming-27-led-curved-fhd-freesync-monitor-black/6392867.p?skuId=6392867
# 13 https://www.bestbuy.com/site/samsung-s60ua-27-qhd-led-monitor-monitor-with-hdr-hdmi-usb-black/6468699.p?skuId=6468699
# 14 https://www.bestbuy.com/site/viewsonic-22-lcd-fhd-monitor-displayport-vga-hdmi-silver/5451402.p?skuId=5451402
# 15 https://www.bestbuy.com/site/alienware-aw2521h-25-ips-led-fhd-g-sync-gaming-monitor-with-hdr10-hdmi-displayport-dark-side-of-the-moon/6453112.p?skuId=6453112
# 16 https://www.bestbuy.com/site/acer-predator-x25-bmiiprzx-g-sync-gaming-monitor/6451654.p?skuId=6451654
# 17 https://www.bestbuy.com/site/lg-ultragear-38-ips-led-ultrawide-hd-g-sync-monitor-hdmi-black/6390310.p?skuId=6390310
# 18 https://www.bestbuy.com/site/benq-zowie-xl2540k-24-5-lcd-esports-gaming-monitor-black/6486236.p?skuId=6486236
# 19 https://www.bestbuy.com/site/razer-raptor27-gaming-led-qhdfreesync-and-g-sync-compatable-monitor-with-hdr-hdmi-displayport-usb-type-c-black/6434259.p?skuId=6434259
# 20 https://www.bestbuy.com/site/viewsonic-15-6-lcd-fhd-monitor-displayport-vga-usb-hdmi/6428015.p?skuId=6428015
# 21 https://www.bestbuy.com/site/samsung-odyssey-gaming-crg5-series-24-led-curved-fhd-freesync-monitor-black/6395561.p?skuId=6395561
# 22 https://www.bestbuy.com/site/lg-32-ultrafine-ips-led-4k-uhd-freesync-monitor-with-hdr-displayport-hdmi-thunderbolt/6314048.p?skuId=6314048
# 23 https://www.bestbuy.com/site/aoc-15-6-ips-portable-usb-c-touch-monitor-black/6437798.p?skuId=6437798
# 24 https://www.bestbuy.com/site/lg-24-ips-fhd-monitor-black/6316146.p?skuId=6316146
# 25 https://www.bestbuy.com/site/benq-gl2780-27-1080p-monitor--75-hz-for-gaming--proprietary-eye-care-tech-adaptive-brightness-for-image-quality-black/6376576.p?skuId=6376576
# 26 https://www.bestbuy.com/site/viewsonic-27-lcd-fhd-monitor-displayport-vga-hdmi-black/5762104.p?skuId=5762104
# 27 https://www.bestbuy.com/site/hp-27-ips-qhd-amd-freesync-monitor-silver/6483567.p?skuId=6483567
# 28 https://www.bestbuy.com/site/viewsonic-vg2755-2k-24-inch-ips-1440p-monitor-with-usb-3-1-type-c-hdmi-displayport-and-40-degree-tilt-ergonomics-black/6321203.p?skuId=6321203
# 29 https://www.bestbuy.com/site/dell-27-lcd-fhd-monitor-displayport-usb-hdmi-black-silver/6473517.p?skuId=6473517
# 30 https://www.bestbuy.com/site/asus-tuf-vg27bq-widescreen-lcd-monitor-black-black/6456074.p?skuId=6456074
# 31 https://www.bestbuy.com/site/viewsonic-27-lcd-fhd-monitor-displayport-vga-hdmi-black/5386124.p?skuId=5386124
# 32 https://www.bestbuy.com/site/benq-designvue-pd-series-pd2700u-27-ips-led-4k-uhd-monitor-displayport-mini-displayport-hdmi-black/6325588.p?skuId=6325588
# 33 https://www.bestbuy.com/site/msi-led-monitor-displayport-hdmi-white/6406791.p?skuId=6406791
# 34 https://www.bestbuy.com/site/viewsonic-27-lcd-curved-fhd-monitor-displayport-hdmi/6441563.p?skuId=6441563
# 35 https://www.bestbuy.com/site/dell-27-lcd-monitor-displayport-vga-black/6483605.p?skuId=6483605
# 36 https://www.bestbuy.com/site/asus-proart-32-ips-led-4k-monitor-with-usb-c-and-height-adjustable-displayporthdmi/6501312.p?skuId=6501312
# 37 https://www.bestbuy.com/site/lg-24-taa-ips-fhd-monitor-black/6348589.p?skuId=6348589
# 38 https://www.bestbuy.com/site/lg-22-class-ips-fhd-monitor-black/6239932.p?skuId=6239932
# 39 https://www.bestbuy.com/site/lg-34-ips-led-ultrawide-wqhd-monitor-with-freesync-and-hdr-10-black/6437469.p?skuId=6437469
# 40 https://www.bestbuy.com/site/benq-el2870u-27-9-hdr-led-4k-uhd-freesync-monitor-displayport-hdmi-metallic-gray/6186701.p?skuId=6186701
# 41 https://www.bestbuy.com/site/acer-cb282k-smiiprx-28-uhd-monitor-hdmi/6424316.p?skuId=6424316
# 42 https://www.bestbuy.com/site/benq-zowie-24-esports-gaming-monitor-xl2411k/6439475.p?skuId=6439475
# 43 https://www.bestbuy.com/site/lg-27-ips-hdr-uhd-4k-monitor-black/6458180.p?skuId=6458180
# 44 https://www.bestbuy.com/site/viewsonic-omni-vx2718-2kpc-mhd-27-inch-curved-1440p-1ms-165hz-gaming-monitor-with-adaptive-sync-hdmi-and-display-port/6469392.p?skuId=6469392
# 45 https://www.bestbuy.com/site/lg-ultragear-27-ips-led-qhd-freesync-and-g-sync-compatible-monitor-with-hdr-displayport-hdmi-black/6401809.p?skuId=6401809
# 46 https://www.bestbuy.com/site/corsair-xeneon-32qhd165-32-ips-led-qhd-freesync-premium-monitor-and-g-sync-compatible-with-hdr400-165hz-dp-hdmi-and-usb-c-black/6478468.p?skuId=6478468
# 47 https://www.bestbuy.com/site/aoc-19-5-led-hd-monitor-black/6333335.p?skuId=6333335
# 48 https://www.bestbuy.com/site/dell-ultrasharp-u3219q-widescreen-lcd-monitor-black-black/6318433.p?skuId=6318433
# 49 https://www.bestbuy.com/site/msi-optix-g271-27-144hz-fhd-ips-freesync-monitor-black/6406780.p?skuId=6406780
# 50 https://www.bestbuy.com/site/asus-rog-swift-24-5-fast-ips-fhd-360hz-1ms-g-sync-gaming-monitor-with-hdr-hdmidisplayportusb/6452318.p?skuId=6452318
# 51 https://www.bestbuy.com/site/dell-23-8-lcd-monitor-displayport-vga-hdmi-black/6486167.p?skuId=6486167
# 52 https://www.bestbuy.com/site/samsung-odyssey-g5-32-ips-1ms-qhd-freesync-premium-g-sync-compatible-165hz-gaming-monitor-black/6500801.p?skuId=6500801
# 53 https://www.bestbuy.com/site/viewsonic-vg2448_h2-24-inch-dual-pack-head-only-ips-1080p-monitors-with-hdmi-displayport-usb-for-home-and-office-black/6325598.p?skuId=6325598
# 54 https://www.bestbuy.com/site/asus-tuf-31-5-curved-qhd-165hz-1ms-1440p-freesync-premium-gaming-monitor-displayporthdmi/6452917.p?skuId=6452917
# 55 https://www.bestbuy.com/site/asus-rog-swift-24-5-fast-ips-fhd-360hz-1ms-g-sync-gaming-monitor-with-hdr-hdmidisplayportusb/6431892.p?skuId=6431892
# 56 https://www.bestbuy.com/site/dell-p1917s-lcd-monitor-black-black/6465150.p?skuId=6465150
# 57 https://www.bestbuy.com/site/asus-proart-pa278qv-27-wqhd-lcd-monitor-displayport-hdmi-usb-black/6424478.p?skuId=6424478
# 58 https://www.bestbuy.com/site/samsung-s65ua-series-34-ultra-wqhd-monitor-usb-c-usb-lan-hdmi-black/6469272.p?skuId=6469272
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /var/folders/4q/s5vk58v95472hjx15zb8y_940000gn/T/ipykernel_56759/1208360503.py in <module>
#       3 for product in products:
#       4     index = products.index(product)
# ----> 5     driver.get(product)
#       6     soup = BeautifulSoup(driver.page_source, 'html.parser')
#       7     time.sleep(1 + 2*random.random())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     435         Loads a web page in the current browser session.
#     436         """
# --> 437         self.execute(Command.GET, {'url': url})
#     438
#     439     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     423         response = self.command_executor.execute(driver_command, params)
#     424         if response:
# --> 425             self.error_handler.check_response(response)
#     426             response['value'] = self._unwrap_value(
#     427                 response.get('value', None))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: target frame detached
#   (Session info: chrome=101.0.4951.64)
# Stacktrace:
# 0   chromedriver                        0x00000001008933d9 chromedriver + 5104601
# 1   chromedriver                        0x0000000100823bf3 chromedriver + 4647923
# 2   chromedriver                        0x00000001004149ff chromedriver + 391679
# 3   chromedriver                        0x00000001003ffa5c chromedriver + 305756
# 4   chromedriver                        0x00000001003feb6a chromedriver + 301930
# 5   chromedriver                        0x00000001003ff06c chromedriver + 303212
# 6   chromedriver                        0x00000001003fefc4 chromedriver + 303044
# 7   chromedriver                        0x000000010040612c chromedriver + 332076
# 8   chromedriver                        0x0000000100400358 chromedriver + 308056
# 9   chromedriver                        0x0000000100400918 chromedriver + 309528
# 10  chromedriver                        0x00000001004006ca chromedriver + 308938
# 11  chromedriver                        0x00000001003ffc67 chromedriver + 306279
# 12  chromedriver                        0x00000001003feb6a chromedriver + 301930
# 13  chromedriver                        0x00000001003ff06c chromedriver + 303212
# 14  chromedriver                        0x00000001003fefc4 chromedriver + 303044
# 15  chromedriver                        0x000000010040612c chromedriver + 332076
# 16  chromedriver                        0x0000000100400358 chromedriver + 308056
# 17  chromedriver                        0x0000000100400918 chromedriver + 309528
# 18  chromedriver                        0x00000001004006ca chromedriver + 308938
# 19  chromedriver                        0x00000001003ffc67 chromedriver + 306279
# 20  chromedriver                        0x00000001003feb6a chromedriver + 301930
# 21  chromedriver                        0x00000001003ff06c chromedriver + 303212
# 22  chromedriver                        0x00000001003fefc4 chromedriver + 303044
# 23  chromedriver                        0x000000010040612c chromedriver + 332076
# 24  chromedriver                        0x0000000100400358 chromedriver + 308056
# 25  chromedriver                        0x0000000100400918 chromedriver + 309528
# 26  chromedriver                        0x00000001004006ca chromedriver + 308938
# 27  chromedriver                        0x00000001003ffc67 chromedriver + 306279
# 28  chromedriver                        0x00000001003feb6a chromedriver + 301930
# 29  chromedriver                        0x00000001003ff06c chromedriver + 303212
# 30  chromedriver                        0x00000001003fefc4 chromedriver + 303044
# 31  chromedriver                        0x000000010040612c chromedriver + 332076
# 32  chromedriver                        0x0000000100400358 chromedriver + 308056
# 33  chromedriver                        0x0000000100400918 chromedriver + 309528
# 34  chromedriver                        0x00000001004006ca chromedriver + 308938
# 35  chromedriver                        0x00000001003ffc67 chromedriver + 306279
# 36  chromedriver                        0x00000001003feb6a chromedriver + 301930
# 37  chromedriver                        0x00000001003ff06c chromedriver + 303212
# 38  chromedriver                        0x00000001003fefc4 chromedriver + 303044
# 39  chromedriver                        0x000000010040612c chromedriver + 332076
# 40  chromedriver                        0x0000000100400358 chromedriver + 308056
# 41  chromedriver                        0x0000000100400918 chromedriver + 309528
# 42  chromedriver                        0x00000001004006ca chromedriver + 308938
# 43  chromedriver                        0x00000001003ffc67 chromedriver + 306279
# 44  chromedriver                        0x00000001003ff423 chromedriver + 304163
# 45  chromedriver                        0x00000001003ff2b3 chromedriver + 303795
# 46  chromedriver                        0x0000000100415fe2 chromedriver + 397282
# 47  chromedriver                        0x000000010047983c chromedriver + 804924
# 48  chromedriver                        0x00000001004675b3 chromedriver + 730547
# 49  chromedriver                        0x000000010043d139 chromedriver + 557369
# 50  chromedriver                        0x000000010043e165 chromedriver + 561509
# 51  chromedriver                        0x000000010085239d chromedriver + 4838301
# 52  chromedriver                        0x000000010086acde chromedriver + 4938974
# 53  chromedriver                        0x000000010086fb5e chromedriver + 4959070
# 54  chromedriver                        0x000000010086b94a chromedriver + 4942154
# 55  chromedriver                        0x000000010084733c chromedriver + 4793148
# 56  chromedriver                        0x00000001008853b8 chromedriver + 5047224
# 57  chromedriver                        0x000000010088553f chromedriver + 5047615
# 58  chromedriver                        0x000000010089a705 chromedriver + 5134085
# 59  libsystem_pthread.dylib             0x00007ff812af94e1 _pthread_start + 125
# 60  libsystem_pthread.dylib             0x00007ff812af4f6b thread_start + 15

# %%
# print({"linklink":len(linklink),"Refresh_Rate":len(Refresh_Rate),"Resolution":len(Resolution),
#        "Contrast_Ratio":len(Contrast_Ratio),"Response_Time":len(Response_Time),
#        "Synchronization_Technology":len(Synchronization_Technology),"Panel_Type":len(Panel_Type), 
#        "Curved_Screen":len(Curved_Screen),
#        "Pixel_Density":len(Pixel_Density),"Brightness":len(Brightness),"Screen_Size":len(Screen_Size),
#        "HDR":len(HDR),"Smart_Display":len(Smart_Display),"Touch_Screen":len(Touch_Screen),
#        "Quantum_Dot_Technology":len(Quantum_Dot_Technology),"Headphone_Jack":len(Headphone_Jack),
#        "Voice_Assistant":len(Voice_Assistant),"Wall_Mountable":len(Wall_Mountable),"Anti_Glare":len(Anti_Glare),
#        "Speaker":len(Speaker),"Webcam":len(Webcam),"Power_Consumption":len(Power_Consumption),"Weight":len(Weight),
#        "Anti_Glare":len(Anti_Glare)
      
#       })

# %%
import pandas as pd
features= pd.DataFrame(
    {'linklink': linklink,
     'Refresh_Rate' : Refresh_Rate,
     'Resolution':Resolution,
     'Contrast_Ratio':Contrast_Ratio,
     'Response_Time':Response_Time,
     'Synchronization_Technology': Synchronization_Technology,
     'Panel_Type':Panel_Type,
     'Curved_Screen': Curved_Screen,
     'Pixel_Density' : Pixel_Density,
     'Contrast_Ratio':Contrast_Ratio,
     'Brightness':Brightness,
     'Screen_Size': Screen_Size,
     'HDR':HDR,
     'Smart_Display':Smart_Display,
     'Touch_Screen':Touch_Screen,
     'Quantum_Dot_Technology':Quantum_Dot_Technology,
     'Headphone_Jack':Headphone_Jack,
     'Voice_Assistant':Voice_Assistant,
     'Wall_Mountable':Wall_Mountable,
     'Anti_Glare':Anti_Glare,
     'Speaker':Speaker,
     'Webcam':Webcam,
     'Power_Consumption':Power_Consumption,
     'Weight':Weight     
    })
features
# Out:
#                                               linklink Refresh_Rate  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...           75
# 1    https://www.bestbuy.com/site/samsung-390-serie...           60
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...           75
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...          165
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...           60
# ..                                                 ...          ...
# 224  https://www.bestbuy.com/site/asus-tuf-31-5-cur...          165
# 225  https://www.bestbuy.com/site/asus-rog-swift-24...          360
# 226  https://www.bestbuy.com/site/dell-p1917s-lcd-m...           60
# 227  https://www.bestbuy.com/site/asus-proart-pa278...           75
# 228  https://www.bestbuy.com/site/samsung-s65ua-ser...          100
#
#       Resolution Contrast_Ratio Response_Time  \
# 0    1920 x 1080           1000             5
# 1    1920 x 1080           3000             4
# 2    2560 x 1080           1000             5
# 3    2560 x 1440           3000             2
# 4    3840 x 2160           1000             4
# ..           ...            ...           ...
# 224  2560 x 1440           3000             1
# 225  1920 x 1080           1000             1
# 226  1280 x 1024           1000             6
# 227  2560 x 1440      100000000             5
# 228  3440 x 1440           4000             5
#
#                Synchronization_Technology      Panel_Type Curved_Screen  \
# 0            FreeSync (AMD Adaptive Sync)             IPS            No
# 1            FreeSync (AMD Adaptive Sync)              VA           Yes
# 2            FreeSync (AMD Adaptive Sync)             IPS            No
# 3    FreeSync Premium (AMD Adaptive Sync)              VA           Yes
# 4            FreeSync (AMD Adaptive Sync)             IPS            No
# ..                                    ...             ...           ...
# 224          FreeSync (AMD Adaptive Sync)              VA           Yes
# 225          FreeSync (AMD Adaptive Sync)  Not Applicable            No
# 226                                 VSync             IPS            No
# 227                        Not Applicable             IPS            No
# 228          FreeSync (AMD Adaptive Sync)              VA           Yes
#
#     Pixel_Density Brightness  ... Touch_Screen Quantum_Dot_Technology  \
# 0              92        250  ...           No                     No
# 1            None        250  ...           No                   None
# 2               0        250  ...           No                     No
# 3              93        350  ...           No                     No
# 4             157        300  ...           No                     No
# ..            ...        ...  ...          ...                    ...
# 224          None        400  ...         None                   None
# 225          None        400  ...         None                   None
# 226          None        250  ...           No                   None
# 227          None        350  ...           No                   None
# 228          None        300  ...         None                   None
#
#     Headphone_Jack Voice_Assistant Wall_Mountable Anti_Glare Speaker Webcam  \
# 0               No              No            Yes       None      No     No
# 1              Yes              No            Yes         No      No     No
# 2              Yes  Not Applicable            Yes        Yes      No     No
# 3              Yes  Not Applicable            Yes        Yes      No     No
# 4               No              No            Yes       None      No     No
# ..             ...             ...            ...        ...     ...    ...
# 224           None            None            Yes       None     Yes     No
# 225           None            None             No       None      No     No
# 226           None              No            Yes       None      No     No
# 227           None            None            Yes       None     Yes     No
# 228           None            None            Yes       None      No     No
#
#     Power_Consumption Weight
# 0                 35    5.95
# 1                 25     7.3
# 2                 39    13.1
# 3               19.9    22.4
# 4                 40    12.8
# ..                ...    ...
# 224              None  20.28
# 225              None  15.65
# 226               14    5.73
# 227              None  17.02
# 228              None   16.8
#
# [229 rows x 23 columns]

# %%
# Save the data to local 
features.to_csv('Monitor_features.csv',index=False)

# %% [markdown]
# #### 5. Merge dataframes

# %%
info=pd.read_csv("Monitor_info.csv")
features=pd.read_csv("Monitor_features.csv")

# %%
info
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/apple-studio-disp...
# 547  https://www.bestbuy.com/site/dell-geek-squad-c...
# 548  https://www.bestbuy.com/site/dell-geek-squad-c...
# 549  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 550  https://www.bestbuy.com/site/acer-predator-xb3...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 546  Apple - Studio Display - Standard Glass Tilt a...    Apple     $1,999.99
# 547  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 548  Dell - Geek Squad Certified Refurbished UltraS...     Dell     $3,599.99
# 549  HP - Geek Squad Certified Refurbished 23.8" IP...       HP       $179.99
# 550  Acer Predator XB3 - 27" Display WQHD 2560x1440...     Acer       $414.99
#
#     rating review_count
# 0      4.6         1838
# 1      4.7         5106
# 2      4.5          425
# 3      4.8          277
# 4      4.6         1840
# ..     ...          ...
# 546    Yet          Yet
# 547    Yet          Yet
# 548    Yet          Yet
# 549    Yet          Yet
# 550    Yet          Yet
#
# [551 rows x 6 columns]

# %%
features
# Out:
#                                               linklink Refresh_Rate  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...           75
# 1    https://www.bestbuy.com/site/samsung-390-serie...           60
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...           75
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...          165
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...           60
# ..                                                 ...          ...
# 546  https://www.bestbuy.com/site/apple-studio-disp...           60
# 547  https://www.bestbuy.com/site/dell-geek-squad-c...           60
# 548  https://www.bestbuy.com/site/dell-geek-squad-c...           60
# 549  https://www.bestbuy.com/site/hp-geek-squad-cer...           75
# 550  https://www.bestbuy.com/site/acer-predator-xb3...          165
#
#     Contrast_Ratio Response_Time            Synchronization_Technology  \
# 0             1000             5          FreeSync (AMD Adaptive Sync)
# 1             3000             4          FreeSync (AMD Adaptive Sync)
# 2             1000             5          FreeSync (AMD Adaptive Sync)
# 3             3000             2  FreeSync Premium (AMD Adaptive Sync)
# 4             1000             4          FreeSync (AMD Adaptive Sync)
# ..             ...           ...                                   ...
# 546           1000          None                        Not Applicable
# 547           1300             4          FreeSync (AMD Adaptive Sync)
# 548        1000000             5                                  None
# 549       10000000             5          FreeSync (AMD Adaptive Sync)
# 550      100000000             1                        Not Applicable
#
#          Panel_Type Curved_Screen Pixel_Density Brightness Screen_Size  ...  \
# 0               IPS            No            92        250          24  ...
# 1                VA           Yes          None        250          24  ...
# 2               IPS            No             0        250          34  ...
# 3                VA           Yes            93        350          32  ...
# 4               IPS            No           157        300          28  ...
# ..              ...           ...           ...        ...         ...  ...
# 546  Retina Display            No          None        600          27  ...
# 547             IPS            No          None        350          27  ...
# 548             IPS            No           163        350        31.5  ...
# 549             IPS            No            93        300        23.8  ...
# 550              VA            No          None        350          27  ...
#
#     Touch_Screen Quantum_Dot_Technology Headphone_Jack Voice_Assistant  \
# 0             No                     No             No              No
# 1             No                   None            Yes              No
# 2             No                     No            Yes  Not Applicable
# 3             No                     No            Yes  Not Applicable
# 4             No                     No             No              No
# ..           ...                    ...            ...             ...
# 546         None                   None           None            None
# 547           No                   None            Yes  Not Applicable
# 548           No                   None             No            None
# 549         None                   None           None            None
# 550         None                   None           None            None
#
#     Wall_Mountable Anti_Glare Speaker Webcam Power_Consumption Weight
# 0              Yes       None      No     No               35    5.95
# 1              Yes         No      No     No               25     7.3
# 2              Yes        Yes      No     No               39    13.1
# 3              Yes        Yes      No     No             19.9    22.4
# 4              Yes       None      No     No               40    12.8
# ..             ...        ...     ...    ...               ...    ...
# 546             No       None     Yes    Yes              None   16.9
# 547            Yes        Yes     Yes     No               28    14.1
# 548            Yes        Yes      No     No               70    38.1
# 549           None        Yes    None     No               20     6.3
# 550             No       None      No     No              None    8.4
#
# [551 rows x 22 columns]

# %%
monitor=pd.merge(info, features, left_on="product_link",right_on="linklink")
monitor.drop(columns=['linklink'],inplace=True)

# %%
monitor
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/apple-studio-disp...
# 547  https://www.bestbuy.com/site/dell-geek-squad-c...
# 548  https://www.bestbuy.com/site/dell-geek-squad-c...
# 549  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 550  https://www.bestbuy.com/site/acer-predator-xb3...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 546  Apple - Studio Display - Standard Glass Tilt a...    Apple     $1,999.99
# 547  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 548  Dell - Geek Squad Certified Refurbished UltraS...     Dell     $3,599.99
# 549  HP - Geek Squad Certified Refurbished 23.8" IP...       HP       $179.99
# 550  Acer Predator XB3 - 27" Display WQHD 2560x1440...     Acer       $414.99
#
#     rating review_count Refresh_Rate Contrast_Ratio Response_Time  \
# 0      4.6         1838           75           1000             5
# 1      4.7         5106           60           3000             4
# 2      4.5          425           75           1000             5
# 3      4.8          277          165           3000             2
# 4      4.6         1840           60           1000             4
# ..     ...          ...          ...            ...           ...
# 546    Yet          Yet           60           1000          None
# 547    Yet          Yet           60           1300             4
# 548    Yet          Yet           60        1000000             5
# 549    Yet          Yet           75       10000000             5
# 550    Yet          Yet          165      100000000             1
#
#                Synchronization_Technology  ... Touch_Screen  \
# 0            FreeSync (AMD Adaptive Sync)  ...           No
# 1            FreeSync (AMD Adaptive Sync)  ...           No
# 2            FreeSync (AMD Adaptive Sync)  ...           No
# 3    FreeSync Premium (AMD Adaptive Sync)  ...           No
# 4            FreeSync (AMD Adaptive Sync)  ...           No
# ..                                    ...  ...          ...
# 546                        Not Applicable  ...         None
# 547          FreeSync (AMD Adaptive Sync)  ...           No
# 548                                  None  ...           No
# 549          FreeSync (AMD Adaptive Sync)  ...         None
# 550                        Not Applicable  ...         None
#
#     Quantum_Dot_Technology Headphone_Jack Voice_Assistant Wall_Mountable  \
# 0                       No             No              No            Yes
# 1                     None            Yes              No            Yes
# 2                       No            Yes  Not Applicable            Yes
# 3                       No            Yes  Not Applicable            Yes
# 4                       No             No              No            Yes
# ..                     ...            ...             ...            ...
# 546                   None           None            None             No
# 547                   None            Yes  Not Applicable            Yes
# 548                   None             No            None            Yes
# 549                   None           None            None           None
# 550                   None           None            None             No
#
#     Anti_Glare Speaker Webcam Power_Consumption Weight
# 0         None      No     No               35    5.95
# 1           No      No     No               25     7.3
# 2          Yes      No     No               39    13.1
# 3          Yes      No     No             19.9    22.4
# 4         None      No     No               40    12.8
# ..         ...     ...    ...               ...    ...
# 546       None     Yes    Yes              None   16.9
# 547        Yes     Yes     No               28    14.1
# 548        Yes      No     No               70    38.1
# 549        Yes    None     No               20     6.3
# 550       None      No     No              None    8.4
#
# [551 rows x 27 columns]

# %%
# Save the data to local 
monitor.to_csv('Monitor.csv',index=False)

# %% [markdown]
# ### The above data scraping was made on May 14, Saturday. Given that my target is the real time prices of monitors on BestBuy, monitor listings and prices are likely to change over time, I repeated the scraping for the date May 17, Tuesday. Other features such as rating, review_count are likely to change as well.

# %%
pages=['https://www.bestbuy.com/site/searchpage.jsp?id=pcat17071&st=monitor']
for i in range(2,24):
    new_url = 'https://www.bestbuy.com/site/searchpage.jsp?cp='+str(i)+'&id=pcat17071&st=monitor'
    pages.append(new_url)
pages[-3:]
# Out:
# ['https://www.bestbuy.com/site/searchpage.jsp?cp=21&id=pcat17071&st=monitor',
#  'https://www.bestbuy.com/site/searchpage.jsp?cp=22&id=pcat17071&st=monitor',
#  'https://www.bestbuy.com/site/searchpage.jsp?cp=23&id=pcat17071&st=monitor']

# %%
main_page="https://www.bestbuy.com"
product_link=[]
product_name=[]
brand=[]
price=[]
rating=[]
review_count=[]

# %%
for page in pages:
    driver.get(page)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    time.sleep(2)
    
    ratings=[item.text.split(" ")[1] for item in soup.find(class_="sku-item-list")('p',class_="visually-hidden")]
    rating.extend(ratings)
    reviews=[item.text.split(" ")[-2] for item in soup.find(class_="sku-item-list")('p',class_="visually-hidden")]   
    review_count.extend(reviews)
    
    for ol in soup.find(class_="sku-item-list"):
        for li in ol.find_all('h4'):
            for link in li.find_all('a'):
                product_link.append(main_page+link['href'])
                product_name.append(link.text)
                brand.append(link.text.split(' ')[0])

        for price_ in ol.find_all('div', class_="price-block"):
            price.append(price_('span')[0].text.split(">$")[-1])

# %%
import pandas as pd
df1= pd.DataFrame(
    {'product_link': product_link,
     'product_name' : product_name,
     'brand':brand,
     'current_price':price,
     'rating': rating,
     'review_count':review_count
    })
df1.drop_duplicates(inplace=True)
df1
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/viewsonic-va2447-...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-24-ips-led-fhd...
# 3    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 4    https://www.bestbuy.com/site/hp-24-ips-led-fhd...
# ..                                                 ...
# 570  https://www.bestbuy.com/site/geek-squad-certif...
# 571  https://www.bestbuy.com/site/geek-squad-certif...
# 572  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 573  https://www.bestbuy.com/site/dell-geek-squad-c...
# 574  https://www.bestbuy.com/site/lg-geek-squad-cer...
#
#                                           product_name      brand  \
# 0    ViewSonic VA2447-MH 24 Inch Full HD 1080p Moni...  ViewSonic
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...    Samsung
# 2    LG - 24" IPS LED FHD FreeSync Monitor (HDMI, V...         LG
# 3    LG 34” UltraWide Full HD HDR Monitor with Free...         LG
# 4    HP - 24" IPS LED FHD FreeSync Monitor (HDMI, V...         HP
# ..                                                 ...        ...
# 570  Geek Squad Certified Refurbished OMEN X by HP ...       Geek
# 571  Geek Squad Certified Refurbished OMEN X by HP ...       Geek
# 572  HP - Geek Squad Certified Refurbished 27" IPS ...         HP
# 573  Dell - Geek Squad Certified Refurbished 27" IP...       Dell
# 574  LG - Geek Squad Certified Refurbished UltraFin...         LG
#
#     current_price rating review_count
# 0         $139.99    Yet          Yet
# 1         $139.99    4.7         5111
# 2         $129.99    4.6         2728
# 3         $329.99    4.5          433
# 4         $149.99    4.7          629
# ..            ...    ...          ...
# 570       $427.99    Yet          Yet
# 571       $427.99    Yet          Yet
# 572       $249.99    Yet          Yet
# 573       $278.99    Yet          Yet
# 574       $629.99    Yet          Yet
#
# [551 rows x 6 columns]

# %%
# Save the data to local   
df1.to_csv('Monitor_info_1.csv',index=False)

# %%
df1=pd.read_csv('Monitor_info_1.csv')
df1
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/viewsonic-va2447-...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-24-ips-led-fhd...
# 3    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 4    https://www.bestbuy.com/site/hp-24-ips-led-fhd...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/geek-squad-certif...
# 547  https://www.bestbuy.com/site/geek-squad-certif...
# 548  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 549  https://www.bestbuy.com/site/dell-geek-squad-c...
# 550  https://www.bestbuy.com/site/lg-geek-squad-cer...
#
#                                           product_name      brand  \
# 0    ViewSonic VA2447-MH 24 Inch Full HD 1080p Moni...  ViewSonic
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...    Samsung
# 2    LG - 24" IPS LED FHD FreeSync Monitor (HDMI, V...         LG
# 3    LG 34” UltraWide Full HD HDR Monitor with Free...         LG
# 4    HP - 24" IPS LED FHD FreeSync Monitor (HDMI, V...         HP
# ..                                                 ...        ...
# 546  Geek Squad Certified Refurbished OMEN X by HP ...       Geek
# 547  Geek Squad Certified Refurbished OMEN X by HP ...       Geek
# 548  HP - Geek Squad Certified Refurbished 27" IPS ...         HP
# 549  Dell - Geek Squad Certified Refurbished 27" IP...       Dell
# 550  LG - Geek Squad Certified Refurbished UltraFin...         LG
#
#     current_price rating review_count
# 0         $139.99    Yet          Yet
# 1         $139.99    4.7         5111
# 2         $129.99    4.6         2728
# 3         $329.99    4.5          433
# 4         $149.99    4.7          629
# ..            ...    ...          ...
# 546       $427.99    Yet          Yet
# 547       $427.99    Yet          Yet
# 548       $249.99    Yet          Yet
# 549       $278.99    Yet          Yet
# 550       $629.99    Yet          Yet
#
# [551 rows x 6 columns]

# %%
linklink=[]
Refresh_Rate=[]
Resolution=[]
Contrast_Ratio=[]
Response_Time=[]
Display_Type=[]
Panel_Type=[]
Synchronization_Technology=[]
Curved_Screen=[]
Pixel_Density=[]
Brightness=[]
Screen_Size=[]
HDR=[]
Smart_Display=[]
Touch_Screen=[]
Quantum_Dot_Technology=[]
Headphone_Jack=[]
Voice_Assistant=[]
Wall_Mountable=[]
Speaker=[]
Webcam=[]
Weight=[]
Power_Consumption=[]
Anti_Glare=[]

# %%
products=list(df1['product_link'])[0:]

for product in products:
    driver.get(product)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    time.sleep(1 + 2*random.random())
    linklink.append(product)
    
    #Refresh_Rate
    refresh=soup.find(class_="display-name v-fw-medium body-copy", text="Refresh Rate")
    if refresh==None:
        Refresh_Rate.append(None)
    if refresh!=None:
        Refresh_Rate.append(refresh.parent.parent.parent.nextSibling.text.strip("Hz") )
    
    #Resolution
    resolution=soup.find(class_="display-name v-fw-medium body-copy", text="Maximum Resolution")
    if resolution==None:
        Resolution.append(None)
    if resolution!=None:
        Resolution.append(resolution.parent.parent.parent.nextSibling.text)
    
    #Contrast Ratio
    contrast=soup.find(class_="display-name v-fw-medium body-copy", text="Contrast Ratio")
    if contrast==None:
        Contrast_Ratio.append(None)
    if contrast!=None:
        Contrast_Ratio.append(contrast.parent.parent.parent.nextSibling.text[:-2].replace(",",""))
    
    #Response Time
    find_response=soup.find(class_="display-name v-fw-medium body-copy", text="Response Time")
    if find_response==None:
        Response_Time.append(None)
    if find_response!=None:
        Response_Time.append(find_response.parent.parent.parent.nextSibling.text.strip(" milliseconds"))
        
    #Display Type
    display=soup.find(class_="row-title", text=re.compile("Display Type"))
    if display==None:
        Display_Type.append(None)
    if display!=None:
        Display_Type.append(display.parent.nextSibling.text)    
    
    #Panel Type
    panel=soup.find(class_="display-name v-fw-medium body-copy", text="Panel Type")
    if panel==None:
        Panel_Type.append(None)
    if panel!=None:
        Panel_Type.append(panel.parent.parent.parent.nextSibling.text)
        
    #Synchronization Technology
    synchronization=soup.find(class_="display-name v-fw-medium body-copy", text="Synchronization Technology")
    if synchronization==None:
        Synchronization_Technology.append(None)
    if synchronization!=None:
        Synchronization_Technology.append(synchronization.parent.parent.parent.nextSibling.text)
    
    #Curved_Screen
    curved=soup.find(class_="row-title", text=re.compile("Curved Screen"))
    if curved==None:
        Curved_Screen.append(None)
    if curved!=None:
        Curved_Screen.append(curved.parent.nextSibling.text)
    
    #Pixel Density
    pixel=soup.find(class_="display-name v-fw-medium body-copy", text="Pixel Density")
    if pixel==None:
        Pixel_Density.append(None)
    if pixel!=None:
        Pixel_Density.append(pixel.parent.parent.parent.nextSibling.text.strip(" pixels per inch"))

    #Brightness
    bright=soup.find(class_="display-name v-fw-medium body-copy", text="Brightness")
    if bright==None:
        Brightness.append(None)
    if bright!=None:
        Brightness.append(bright.parent.parent.parent.nextSibling.text.strip(" candela per square meter"))
                
    ##Screen Size
    size=soup.find(class_="display-name v-fw-medium body-copy", text="Screen Size")
    if size==None:
        Screen_Size.append(None)
    if size!=None:
        Screen_Size.append(size.parent.parent.parent.nextSibling.text.strip(" inches"))  
    
    
    #High Dynamic Range (HDR)
    hdr=soup.find(class_="display-name v-fw-medium body-copy", text="High Dynamic Range (HDR)")
    if hdr==None:
        HDR.append(None)
    if hdr!=None:
        HDR.append(hdr.parent.parent.parent.nextSibling.text)
        
    #Smart Display
    smart=soup.find(class_="display-name v-fw-medium body-copy", text="Smart Display")
    if smart==None:
        Smart_Display.append(None)
    if smart!=None:
        Smart_Display.append(smart.parent.parent.parent.nextSibling.text)

    #Touch Screen
    touch=soup.find(class_="display-name v-fw-medium body-copy", text="Touch Screen")
    if touch==None:
        Touch_Screen.append(None)
    if touch!=None:
        Touch_Screen.append(touch.parent.parent.parent.nextSibling.text)

    #Quantum_Dot_Technology
    quantum=soup.find(class_="display-name v-fw-medium body-copy", text="Quantum Dot Technology")
    if quantum==None:
        Quantum_Dot_Technology.append(None)
    if quantum!=None:
        Quantum_Dot_Technology.append(quantum.parent.parent.parent.nextSibling.text)

    #Headphone_Jack
    headphone=soup.find(class_="display-name v-fw-medium body-copy", text="Headphone Jack")
    if headphone==None:
        Headphone_Jack.append(None)
    if headphone!=None:
        Headphone_Jack.append(headphone.parent.parent.parent.nextSibling.text)

    #Voice Assistant Built-in
    voice=soup.find(class_="display-name v-fw-medium body-copy", text="Voice Assistant Built-in")
    if voice==None:
        Voice_Assistant.append(None)
    if voice!=None:
        Voice_Assistant.append(voice.parent.parent.parent.nextSibling.text)
        
    #Wall Mountable
    mount=soup.find(class_="display-name v-fw-medium body-copy", text="Wall Mountable")
    if mount==None:
        Wall_Mountable.append(None)
    if mount!=None:
        Wall_Mountable.append(mount.parent.parent.parent.nextSibling.text)

    #Integrated Speaker(s)
    speaker=soup.find(class_="row-title", text=re.compile("Speaker"))
    if speaker==None:
        Speaker.append(None)
    if speaker!=None:
        Speaker.append(speaker.parent.nextSibling.text)   

    #Built-In Webcam 
    power=soup.find(class_="row-title", text=re.compile("Power Consumption"))
    if power==None:
        Power_Consumption.append(None)
    if power!=None:
        Power_Consumption.append(power.parent.nextSibling.text[:-5])  
        
    #Weight
    weight=soup.find(class_="display-name v-fw-medium body-copy", text="Product Weight")
    if weight==None:
        Weight.append(None)
    if weight!=None:
        Weight.append(weight.parent.parent.parent.nextSibling.text.strip(" pounds"))
        
    #Power Consumption 
    webcam=soup.find(class_="row-title", text=re.compile("Webcam"))
    if webcam==None:
        Webcam.append(None)
    if webcam!=None:
        Webcam.append(webcam.parent.nextSibling.text)   
        
    #Anti_Glare
    glare=soup.find(class_="display-name v-fw-medium body-copy", text="Anti-Glare")
    if glare==None:
        Anti_Glare.append(None)
    if glare!=None:
        Anti_Glare.append(glare.parent.parent.parent.nextSibling.text)

# %%
features_1= pd.DataFrame(
    {'linklink': linklink,
     'Refresh_Rate' : Refresh_Rate,
     'Resolution':Resolution,
     'Contrast_Ratio':Contrast_Ratio,
     'Response_Time':Response_Time,
     'Synchronization_Technology': Synchronization_Technology,
     'Panel_Type':Panel_Type,
     'Curved_Screen': Curved_Screen,
     'Pixel_Density' : Pixel_Density,
     'Contrast_Ratio':Contrast_Ratio,
     'Brightness':Brightness,
     'Screen_Size': Screen_Size,
     'HDR':HDR,
     'Smart_Display':Smart_Display,
     'Touch_Screen':Touch_Screen,
     'Quantum_Dot_Technology':Quantum_Dot_Technology,
     'Headphone_Jack':Headphone_Jack,
     'Voice_Assistant':Voice_Assistant,
     'Wall_Mountable':Wall_Mountable,
     'Anti_Glare':Anti_Glare,
     'Speaker':Speaker,
     'Webcam':Webcam,
     'Power_Consumption':Power_Consumption,
     'Weight':Weight     
    })
features_1.shape
# Out:
# (551, 22)

# %%
# Save the data to local 
features_1.to_csv('Monitor_features_1.csv',index=False)

# %%
info_1=pd.read_csv("Monitor_info_1.csv")
features_1=pd.read_csv("Monitor_features_1.csv")

# %%
monitor_1=pd.merge(info_1, features_1, left_on="product_link",right_on="linklink")
monitor_1.drop(columns=['linklink'],inplace=True)

# %%
# Save the data to local 
monitor_1.to_csv('Monitor_1.csv',index=False)

# %%
monitor_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 551 entries, 0 to 550
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_link                551 non-null    object
#  1   product_name                551 non-null    object
#  2   brand                       551 non-null    object
#  3   current_price               551 non-null    object
#  4   rating                      551 non-null    object
#  5   review_count                551 non-null    object
#  6   Refresh_Rate                547 non-null    object
#  7   Contrast_Ratio              547 non-null    object
#  8   Response_Time               492 non-null    float64
#  9   Synchronization_Technology  529 non-null    object
#  10  Panel_Type                  544 non-null    object
#  11  Curved_Screen               535 non-null    object
#  12  Pixel_Density               90 non-null     float64
#  13  Brightness                  547 non-null    float64
#  14  Screen_Size                 547 non-null    float64
#  15  HDR                         531 non-null    object
#  16  Smart_Display               152 non-null    object
#  17  Touch_Screen                310 non-null    object
#  18  Quantum_Dot_Technology      93 non-null     object
#  19  Headphone_Jack              275 non-null    object
#  20  Voice_Assistant             187 non-null    object
#  21  Wall_Mountable              537 non-null    object
#  22  Anti_Glare                  318 non-null    object
#  23  Speaker                     522 non-null    object
#  24  Webcam                      522 non-null    object
#  25  Power_Consumption           300 non-null    float64
#  26  Weight                      547 non-null    float64
# dtypes: float64(6), object(21)
# memory usage: 120.5+ KB

# %% [markdown]
# ### Final Data

# %%
monitor=pd.read_csv('Monitor.csv')

# %%
monitor  # Data for May 14
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/apple-studio-disp...
# 547  https://www.bestbuy.com/site/dell-geek-squad-c...
# 548  https://www.bestbuy.com/site/dell-geek-squad-c...
# 549  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 550  https://www.bestbuy.com/site/acer-predator-xb3...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 546  Apple - Studio Display - Standard Glass Tilt a...    Apple     $1,999.99
# 547  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 548  Dell - Geek Squad Certified Refurbished UltraS...     Dell     $3,599.99
# 549  HP - Geek Squad Certified Refurbished 23.8" IP...       HP       $179.99
# 550  Acer Predator XB3 - 27" Display WQHD 2560x1440...     Acer       $414.99
#
#     rating review_count Refresh_Rate Contrast_Ratio  Response_Time  \
# 0      4.6         1838           75           1000            5.0
# 1      4.7         5106           60           3000            4.0
# 2      4.5          425           75           1000            5.0
# 3      4.8          277          165           3000            2.0
# 4      4.6         1840           60           1000            4.0
# ..     ...          ...          ...            ...            ...
# 546    Yet          Yet           60           1000            NaN
# 547    Yet          Yet           60           1300            4.0
# 548    Yet          Yet           60        1000000            5.0
# 549    Yet          Yet           75       10000000            5.0
# 550    Yet          Yet          165      100000000            1.0
#
#                Synchronization_Technology  ... Touch_Screen  \
# 0            FreeSync (AMD Adaptive Sync)  ...           No
# 1            FreeSync (AMD Adaptive Sync)  ...           No
# 2            FreeSync (AMD Adaptive Sync)  ...           No
# 3    FreeSync Premium (AMD Adaptive Sync)  ...           No
# 4            FreeSync (AMD Adaptive Sync)  ...           No
# ..                                    ...  ...          ...
# 546                        Not Applicable  ...          NaN
# 547          FreeSync (AMD Adaptive Sync)  ...           No
# 548                                   NaN  ...           No
# 549          FreeSync (AMD Adaptive Sync)  ...          NaN
# 550                        Not Applicable  ...          NaN
#
#     Quantum_Dot_Technology  Headphone_Jack  Voice_Assistant  Wall_Mountable  \
# 0                       No              No               No             Yes
# 1                      NaN             Yes               No             Yes
# 2                       No             Yes   Not Applicable             Yes
# 3                       No             Yes   Not Applicable             Yes
# 4                       No              No               No             Yes
# ..                     ...             ...              ...             ...
# 546                    NaN             NaN              NaN              No
# 547                    NaN             Yes   Not Applicable             Yes
# 548                    NaN              No              NaN             Yes
# 549                    NaN             NaN              NaN             NaN
# 550                    NaN             NaN              NaN              No
#
#     Anti_Glare Speaker Webcam Power_Consumption Weight
# 0          NaN      No     No              35.0   5.95
# 1           No      No     No              25.0   7.30
# 2          Yes      No     No              39.0  13.10
# 3          Yes      No     No              19.9  22.40
# 4          NaN      No     No              40.0  12.80
# ..         ...     ...    ...               ...    ...
# 546        NaN     Yes    Yes               NaN  16.90
# 547        Yes     Yes     No              28.0  14.10
# 548        Yes      No     No              70.0  38.10
# 549        Yes     NaN     No              20.0   6.30
# 550        NaN      No     No               NaN   8.40
#
# [551 rows x 27 columns]

# %%
monitor_1   # Data for May 17
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/viewsonic-va2447-...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-24-ips-led-fhd...
# 3    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 4    https://www.bestbuy.com/site/hp-24-ips-led-fhd...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/geek-squad-certif...
# 547  https://www.bestbuy.com/site/geek-squad-certif...
# 548  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 549  https://www.bestbuy.com/site/dell-geek-squad-c...
# 550  https://www.bestbuy.com/site/lg-geek-squad-cer...
#
#                                           product_name      brand  \
# 0    ViewSonic VA2447-MH 24 Inch Full HD 1080p Moni...  ViewSonic
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...    Samsung
# 2    LG - 24" IPS LED FHD FreeSync Monitor (HDMI, V...         LG
# 3    LG 34” UltraWide Full HD HDR Monitor with Free...         LG
# 4    HP - 24" IPS LED FHD FreeSync Monitor (HDMI, V...         HP
# ..                                                 ...        ...
# 546  Geek Squad Certified Refurbished OMEN X by HP ...       Geek
# 547  Geek Squad Certified Refurbished OMEN X by HP ...       Geek
# 548  HP - Geek Squad Certified Refurbished 27" IPS ...         HP
# 549  Dell - Geek Squad Certified Refurbished 27" IP...       Dell
# 550  LG - Geek Squad Certified Refurbished UltraFin...         LG
#
#     current_price rating review_count Refresh_Rate Contrast_Ratio  \
# 0         $139.99    Yet          Yet           75           1000
# 1         $139.99    4.7         5111           60           3000
# 2         $129.99    4.6         2728           75           1000
# 3         $329.99    4.5          433           75           1000
# 4         $149.99    4.7          629           70       10000000
# ..            ...    ...          ...          ...            ...
# 546       $427.99    Yet          Yet          240       12000000
# 547       $427.99    Yet          Yet          240       12000000
# 548       $249.99    Yet          Yet           75       10000000
# 549       $278.99    Yet          Yet           60           1300
# 550       $629.99    Yet          Yet           60           1200
#
#      Response_Time    Synchronization_Technology  ... Touch_Screen  \
# 0              5.0                Not Applicable  ...           No
# 1              4.0  FreeSync (AMD Adaptive Sync)  ...           No
# 2              5.0  FreeSync (AMD Adaptive Sync)  ...          NaN
# 3              5.0  FreeSync (AMD Adaptive Sync)  ...           No
# 4              5.0  FreeSync (AMD Adaptive Sync)  ...           No
# ..             ...                           ...  ...          ...
# 546            1.0  FreeSync (AMD Adaptive Sync)  ...          NaN
# 547            1.0  FreeSync (AMD Adaptive Sync)  ...          NaN
# 548            5.0  FreeSync (AMD Adaptive Sync)  ...           No
# 549            4.0  FreeSync (AMD Adaptive Sync)  ...           No
# 550           14.0                           NaN  ...          NaN
#
#     Quantum_Dot_Technology  Headphone_Jack  Voice_Assistant  Wall_Mountable  \
# 0                      NaN             Yes              NaN             Yes
# 1                      NaN             Yes               No             Yes
# 2                      NaN             Yes              NaN             Yes
# 3                       No             Yes   Not Applicable             Yes
# 4                      NaN              No              NaN              No
# ..                     ...             ...              ...             ...
# 546                    NaN             NaN              NaN             Yes
# 547                    NaN             NaN              NaN             Yes
# 548                    NaN              No              NaN              No
# 549                    NaN             Yes   Not Applicable             Yes
# 550                    NaN             NaN              NaN             Yes
#
#     Anti_Glare Speaker Webcam Power_Consumption Weight
# 0          Yes     Yes     No              23.0    7.3
# 1           No      No     No              25.0    7.3
# 2          NaN      No     No              35.0    6.8
# 3          Yes      No     No              39.0   13.1
# 4          Yes      No     No               NaN    5.5
# ..         ...     ...    ...               ...    ...
# 546        Yes      No     No               NaN   13.6
# 547        Yes      No     No               NaN   13.6
# 548        Yes      No    NaN              27.0    8.2
# 549        Yes     Yes     No              28.0   14.1
# 550        NaN     NaN    NaN             140.0   15.4
#
# [551 rows x 27 columns]

# %%
monitor_final=monitor.append(monitor_1)

# %%
monitor_final
# Out:
#                                           product_link  \
# 0    https://www.bestbuy.com/site/samsung-t350-seri...
# 1    https://www.bestbuy.com/site/samsung-390-serie...
# 2    https://www.bestbuy.com/site/lg-34-ultrawide-f...
# 3    https://www.bestbuy.com/site/dell-s3222dgm-32-...
# 4    https://www.bestbuy.com/site/samsung-ur55-seri...
# ..                                                 ...
# 546  https://www.bestbuy.com/site/geek-squad-certif...
# 547  https://www.bestbuy.com/site/geek-squad-certif...
# 548  https://www.bestbuy.com/site/hp-geek-squad-cer...
# 549  https://www.bestbuy.com/site/dell-geek-squad-c...
# 550  https://www.bestbuy.com/site/lg-geek-squad-cer...
#
#                                           product_name    brand current_price  \
# 0    Samsung - T350 Series 24" IPS LED FHD, FreeSyn...  Samsung       $139.99
# 1    Samsung - 390 Series 24" LED Curved FHD FreeSy...  Samsung       $139.99
# 2    LG 34” UltraWide Full HD HDR Monitor with Free...       LG       $299.99
# 3    Dell - S3222DGM 32" LED Curved QHD FreeSync Ga...     Dell       $299.99
# 4    Samsung - UR55 Series 28" IPS 4K UHD Monitor -...  Samsung       $319.99
# ..                                                 ...      ...           ...
# 546  Geek Squad Certified Refurbished OMEN X by HP ...     Geek       $427.99
# 547  Geek Squad Certified Refurbished OMEN X by HP ...     Geek       $427.99
# 548  HP - Geek Squad Certified Refurbished 27" IPS ...       HP       $249.99
# 549  Dell - Geek Squad Certified Refurbished 27" IP...     Dell       $278.99
# 550  LG - Geek Squad Certified Refurbished UltraFin...       LG       $629.99
#
#     rating review_count Refresh_Rate Contrast_Ratio  Response_Time  \
# 0      4.6         1838           75           1000            5.0
# 1      4.7         5106           60           3000            4.0
# 2      4.5          425           75           1000            5.0
# 3      4.8          277          165           3000            2.0
# 4      4.6         1840           60           1000            4.0
# ..     ...          ...          ...            ...            ...
# 546    Yet          Yet          240       12000000            1.0
# 547    Yet          Yet          240       12000000            1.0
# 548    Yet          Yet           75       10000000            5.0
# 549    Yet          Yet           60           1300            4.0
# 550    Yet          Yet           60           1200           14.0
#
#                Synchronization_Technology  ... Touch_Screen  \
# 0            FreeSync (AMD Adaptive Sync)  ...           No
# 1            FreeSync (AMD Adaptive Sync)  ...           No
# 2            FreeSync (AMD Adaptive Sync)  ...           No
# 3    FreeSync Premium (AMD Adaptive Sync)  ...           No
# 4            FreeSync (AMD Adaptive Sync)  ...           No
# ..                                    ...  ...          ...
# 546          FreeSync (AMD Adaptive Sync)  ...          NaN
# 547          FreeSync (AMD Adaptive Sync)  ...          NaN
# 548          FreeSync (AMD Adaptive Sync)  ...           No
# 549          FreeSync (AMD Adaptive Sync)  ...           No
# 550                                   NaN  ...          NaN
#
#     Quantum_Dot_Technology  Headphone_Jack  Voice_Assistant  Wall_Mountable  \
# 0                       No              No               No             Yes
# 1                      NaN             Yes               No             Yes
# 2                       No             Yes   Not Applicable             Yes
# 3                       No             Yes   Not Applicable             Yes
# 4                       No              No               No             Yes
# ..                     ...             ...              ...             ...
# 546                    NaN             NaN              NaN             Yes
# 547                    NaN             NaN              NaN             Yes
# 548                    NaN              No              NaN              No
# 549                    NaN             Yes   Not Applicable             Yes
# 550                    NaN             NaN              NaN             Yes
#
#     Anti_Glare Speaker Webcam Power_Consumption Weight
# 0          NaN      No     No              35.0   5.95
# 1           No      No     No              25.0   7.30
# 2          Yes      No     No              39.0  13.10
# 3          Yes      No     No              19.9  22.40
# 4          NaN      No     No              40.0  12.80
# ..         ...     ...    ...               ...    ...
# 546        Yes      No     No               NaN  13.60
# 547        Yes      No     No               NaN  13.60
# 548        Yes      No    NaN              27.0   8.20
# 549        Yes     Yes     No              28.0  14.10
# 550        NaN     NaN    NaN             140.0  15.40
#
# [1102 rows x 27 columns]

# %%
# Save the data to local   
monitor_final.to_csv('monitor_final.csv',index=False)

# %%
monitor_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1102 entries, 0 to 550
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_link                1102 non-null   object
#  1   product_name                1102 non-null   object
#  2   brand                       1102 non-null   object
#  3   current_price               1102 non-null   object
#  4   rating                      1102 non-null   object
#  5   review_count                1102 non-null   object
#  6   Refresh_Rate                1094 non-null   object
#  7   Contrast_Ratio              1094 non-null   object
#  8   Response_Time               983 non-null    float64
#  9   Synchronization_Technology  1056 non-null   object
#  10  Panel_Type                  1088 non-null   object
#  11  Curved_Screen               1069 non-null   object
#  12  Pixel_Density               184 non-null    float64
#  13  Brightness                  1094 non-null   float64
#  14  Screen_Size                 1094 non-null   float64
#  15  HDR                         1061 non-null   object
#  16  Smart_Display               306 non-null    object
#  17  Touch_Screen                618 non-null    object
#  18  Quantum_Dot_Technology      187 non-null    object
#  19  Headphone_Jack              550 non-null    object
#  20  Voice_Assistant             374 non-null    object
#  21  Wall_Mountable              1073 non-null   object
#  22  Anti_Glare                  638 non-null    object
#  23  Speaker                     1042 non-null   object
#  24  Webcam                      1043 non-null   object
#  25  Power_Consumption           601 non-null    float64
#  26  Weight                      1094 non-null   float64
# dtypes: float64(6), object(21)
# memory usage: 241.1+ KB
